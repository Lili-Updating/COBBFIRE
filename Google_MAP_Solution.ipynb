# %%
import googlemaps
from datetime import datetime
import pandas as pd
import json

# %%
fire_facilities = pd.read_csv("../FireFacilities.csv", usecols=["ADDRESS", "NAME"], skiprows=[28])

# %%
fire_facilities
# Out:
#                           ADDRESS                                 NAME
# 0                   4550 Cowan Rd   Cobb County Fire Station Number 11
# 1               1660 Mars Hill Rd   Cobb County Fire Station Number 18
# 2             3540 Paul Samuel Rd   Cobb County Fire Station Number 24
# 3             3800 Bells Ferry Rd   Cobb County Fire Station Number 16
# 4                 810 Brackett Rd   Cobb County Fire Station Number 12
# 5                 4431 Trickum Rd  Cobb County Fire Station  Number 25
# 6                 2905 Library Ln   Cobb County Fire Station Number 14
# 7                     3892 Oak Ln   Cobb County Fire Station Number 15
# 8                  1298 Hilton Dr   Cobb County Fire Station Number 20
# 9           4400 Lower Roswell Rd   Cobb County Fire Station Number 21
# 10            580 Terrell Mill Rd    Cobb County Fire Station Number 3
# 11                  208 Barber Rd    Cobb County Fire Station Number 2
# 12        1901 Cumberland Parkway    Cobb County Fire Station Number 4
# 13          5656 Mableton Parkway    Cobb County Fire Station Number 1
# 14   5075 Hiram Lithia Springs Rd    Cobb County Fire Station Number 6
# 15                4700 Austell Rd   Cobb County Fire Station Number 22
# 16                    810 Hurt Rd    Cobb County Fire Station Number 7
# 17         2049 Powder Springs Rd   Cobb County Fire Station Number 10
# 18           1500 Powers Ferry Rd   Cobb County Fire Station Number 19
# 19            2380 N Cobb Parkway    Cobb County Fire Station Number 8
# 20            4336 Paces Ferry Rd    Cobb County Fire Station Number 5
# 21               315 Hillcrest Dr    Cobb County Fire Station Number 9
# 22                111 Ridgeway Rd   Cobb County Fire Station Number 17
# 23            4640 Dallas Highway   Cobb County Fire Station Number 13
# 24               3862 Cherokee St   Cobb County Fire Station Number 26
# 25            3470 New Macland Rd   Cobb County Fire Station Number 23
# 26  477 Veterans Memorial Highway   Cobb County Fire Station Number 27
# 27              931 Windy Hill Rd   Cobb County Fire Station Number 30
# 28             3858 Kemp Ridge Rd   Cobb County Fire Station Number 28

# %%
fire_facilities["ADDRESS"] = fire_facilities["ADDRESS"] + ", GA"
origins = fire_facilities["ADDRESS"].tolist()
print origins
# Out:
# ['4550 Cowan Rd, GA', '1660 Mars Hill Rd, GA', '3540 Paul Samuel Rd, GA', '3800 Bells Ferry Rd, GA', '810 Brackett Rd, GA', '4431 Trickum Rd, GA', '2905 Library Ln, GA', '3892 Oak Ln, GA', '1298 Hilton Dr, GA', '4400 Lower Roswell Rd, GA', '580 Terrell Mill Rd, GA', '208 Barber Rd, GA', '1901 Cumberland Parkway, GA', '5656 Mableton Parkway, GA', '5075 Hiram Lithia Springs Rd, GA', '4700 Austell Rd, GA', '810 Hurt Rd, GA', '2049 Powder Springs Rd, GA', '1500 Powers Ferry Rd, GA', '2380 N Cobb Parkway, GA', '4336 Paces Ferry Rd, GA', '315 Hillcrest Dr, GA', '111 Ridgeway Rd, GA', '4640 Dallas Highway, GA', '3862 Cherokee St, GA', '3470 New Macland Rd, GA', '477 Veterans Memorial Highway, GA', '931 Windy Hill Rd, GA', '3858 Kemp Ridge Rd, GA']

# %%
geo = googlemaps.Client(key="AIzaSyBEgx-DDj9TSA22w3orqZ33-Nk115V8W30")

# %%
formatted_address = []
for orgin in origins:
    geocode_result = geo.geocode(orgin)
    formatted_address.append(geocode_result[0]["formatted_address"])
# 20        4336 Paces Ferry Rd, Atlanta, GA 30339, USA
# 21         315 Hillcrest Dr, Montezuma, GA 31063, USA
# 22             111 Ridgeway Rd, Milner, GA 30257, USA
# 23     4640 Dallas Hwy, Powder Springs, GA 30127, USA
# 24           3862 Cherokee St, Acworth, GA 30101, USA
# 25  3470 New MacLand Rd, Powder Springs, GA 30127,...
# 26  477 Veterans Memorial Hwy SW, Mableton, GA 301...
# 27         931 Windy Hill Rd, Marietta, GA 30008, USA
# 28         3858 Kemp Ridge Rd, Acworth, GA 30101, USA

# %%
import pickle
pickle.dump(fire_facilities, open("fire_facilities.p", "wb"))

# %%
picle.load(open("fire_facilities.p", "rb"))

# %%
gmaps = googlemaps.Client(key='AIzaSyBToPoTEF82tkEm9otXFQ2VHgl3bAumGjE')

# %%
origins = fire_facilities["FORMATTED_ADDRESS"].tolist()
print origins
# Out:
# [u'4550 Cowan Rd, Acworth, GA 30101, USA', u'1660 Mars Hill Rd, Acworth, GA 30101, USA', u'3540 Paul Samuel Rd NW, Kennesaw, GA 30152, USA', u'3800 Bells Ferry Rd, Kennesaw, GA 30144, USA', u'810 Brackett Rd, Marietta, GA 30066, USA', u'4431 Trickum Rd, Marietta, GA 30066, USA', u'Library Ln, Marietta, GA 30062, USA', u'3892 Oak Ln, Marietta, GA 30062, USA', u'1298 Hilton Dr, Marietta, GA 30062, USA', u'4400 Lower Roswell Rd, Marietta, GA 30068, USA', u'580 Terrell Mill Rd, Marietta, GA 30067, USA', u'208 Barber Rd, Marietta, GA 30060, USA', u'1901 Cumberland Pkwy SE, Atlanta, GA 30339, USA', u'5656 Mableton Pkwy SW, Mableton, GA 30126, USA', u'5075 Hiram Lithia Springs Rd SW, Powder Springs, GA 30127, USA', u'4700 Austell Rd, Austell, GA 30106, USA', u'810 Hurt Rd, Austell, GA 30106, USA', u'2049 Powder Springs Rd SW, Marietta, GA 30008, USA', u'1500 Powers Ferry Rd SE, Marietta, GA 30067, USA', u'2380 Cobb Pkwy N, Kennesaw, GA 30152, USA', u'4336 Paces Ferry Rd, Atlanta, GA 30339, USA', u'315 Hillcrest Dr, Montezuma, GA 31063, USA', u'111 Ridgeway Rd, Milner, GA 30257, USA', u'4640 Dallas Hwy, Powder Springs, GA 30127, USA', u'3862 Cherokee St, Acworth, GA 30101, USA', u'3470 New MacLand Rd, Powder Springs, GA 30127, USA', u'477 Veterans Memorial Hwy SW, Mableton, GA 30126, USA', u'931 Windy Hill Rd, Marietta, GA 30008, USA', u'3858 Kemp Ridge Rd, Acworth, GA 30101, USA']

# %%
destinations = ["Victoria BC"]
now = datetime.now()
directions_result = gmaps.distance_matrix(origins, destinations)

# %%
print json.dumps(directions_result,indent=4, sort_keys=True)
# Out:
# {
#     "destination_addresses": [
#         "Victoria, BC, Canada"
#     ],
#     "origin_addresses": [
#         "Vancouver, BC, Canada",
#         "Seattle, WA, USA"
#     ],
#     "rows": [
#         {
#             "elements": [
#                 {
#                     "distance": {
#                         "text": "114 km",
#                         "value": 114163
#                     },
#                     "duration": {
#                         "text": "3 hours 12 mins",
#                         "value": 11503
#                     },
#                     "status": "OK"
#                 }
#             ]
#         },
#         {
#             "elements": [
#                 {
#                     "distance": {
#                         "text": "172 km",
#                         "value": 171668
#                     },
#                     "duration": {
#                         "text": "4 hours 39 mins",
#                         "value": 16713
#                     },
#                     "status": "OK"
#                 }
#             ]
#         }
#     ],
#     "status": "OK"
# }
