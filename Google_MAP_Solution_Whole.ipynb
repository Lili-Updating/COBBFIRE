# %%
import googlemaps
from datetime import datetime
import pandas as pd
import json
import pickle

# %%
fire_facilities = pd.read_csv("../FireFacilities.csv", usecols=["ADDRESS", "NAME"], skiprows=[28])

# %%
fire_facilities["ADDRESS"] = fire_facilities["ADDRESS"] + ", GA"
origins = fire_facilities["ADDRESS"].tolist()

# %%
geo = googlemaps.Client(key="AIzaSyBEgx-DDj9TSA22w3orqZ33-Nk115V8W30")

# %%
formatted_address = []
for orgin in origins:
    geocode_result = geo.geocode(orgin)
    formatted_address.append(geocode_result[0]["formatted_address"])
fire_facilities["FORMATTED_ADDRESS"] = formatted_address

# %%
fire_facilities["STATION NUMBER"] = fire_facilities["NAME"].str[-2:]

# %%
fire_facilities["STATION NUMBER"] = fire_facilities["STATION NUMBER"].str.replace(" ", "0")

# %%
pickle.dump(fire_facilities, open("fire_facilities.p", "wb"))

# %%
fire_facilities = pickle.load(open("fire_facilities.p", "rb"))

# %%
fire_facilities
# Out:
#                               ADDRESS                                 NAME  \
# 0                   4550 Cowan Rd, GA   Cobb County Fire Station Number 11
# 1               1660 Mars Hill Rd, GA   Cobb County Fire Station Number 18
# 2             3540 Paul Samuel Rd, GA   Cobb County Fire Station Number 24
# 3             3800 Bells Ferry Rd, GA   Cobb County Fire Station Number 16
# 4                 810 Brackett Rd, GA   Cobb County Fire Station Number 12
# 5                 4431 Trickum Rd, GA  Cobb County Fire Station  Number 25
# 6                 2905 Library Ln, GA   Cobb County Fire Station Number 14
# 7                     3892 Oak Ln, GA   Cobb County Fire Station Number 15
# 8                  1298 Hilton Dr, GA   Cobb County Fire Station Number 20
# 9           4400 Lower Roswell Rd, GA   Cobb County Fire Station Number 21
# 10            580 Terrell Mill Rd, GA    Cobb County Fire Station Number 3
# 11                  208 Barber Rd, GA    Cobb County Fire Station Number 2
# 12        1901 Cumberland Parkway, GA    Cobb County Fire Station Number 4
# 13          5656 Mableton Parkway, GA    Cobb County Fire Station Number 1
# 14   5075 Hiram Lithia Springs Rd, GA    Cobb County Fire Station Number 6
# 15                4700 Austell Rd, GA   Cobb County Fire Station Number 22
# 16                    810 Hurt Rd, GA    Cobb County Fire Station Number 7
# 17         2049 Powder Springs Rd, GA   Cobb County Fire Station Number 10
# 18           1500 Powers Ferry Rd, GA   Cobb County Fire Station Number 19
# 19            2380 N Cobb Parkway, GA    Cobb County Fire Station Number 8
# 20            4336 Paces Ferry Rd, GA    Cobb County Fire Station Number 5
# 21               315 Hillcrest Dr, GA    Cobb County Fire Station Number 9
# 22                111 Ridgeway Rd, GA   Cobb County Fire Station Number 17
# 23            4640 Dallas Highway, GA   Cobb County Fire Station Number 13
# 24               3862 Cherokee St, GA   Cobb County Fire Station Number 26
# 25            3470 New Macland Rd, GA   Cobb County Fire Station Number 23
# 26  477 Veterans Memorial Highway, GA   Cobb County Fire Station Number 27
# 27              931 Windy Hill Rd, GA   Cobb County Fire Station Number 30
# 28             3858 Kemp Ridge Rd, GA   Cobb County Fire Station Number 28
#
#                                     FORMATTED_ADDRESS STATION NUMBER
# 0               4550 Cowan Rd, Acworth, GA 30101, USA             11
# 1           1660 Mars Hill Rd, Acworth, GA 30101, USA             18
# 2     3540 Paul Samuel Rd NW, Kennesaw, GA 30152, USA             24
# 3        3800 Bells Ferry Rd, Kennesaw, GA 30144, USA             16
# 4            810 Brackett Rd, Marietta, GA 30066, USA             12
# 5            4431 Trickum Rd, Marietta, GA 30066, USA             25
# 6                 Library Ln, Marietta, GA 30062, USA             14
# 7                3892 Oak Ln, Marietta, GA 30062, USA             15
# 8             1298 Hilton Dr, Marietta, GA 30062, USA             20
# 9      4400 Lower Roswell Rd, Marietta, GA 30068, USA             21
# 10  580 Terrell Mill Road SE, Marietta, GA 30067, USA             03
# 11             208 Barber Rd, Marietta, GA 30060, USA             02
# 12    1901 Cumberland Pkwy SE, Atlanta, GA 30339, USA             04
# 13     5656 Mableton Pkwy SW, Mableton, GA 30126, USA             01
# 14  5075 Hiram Lithia Springs Rd SW, Powder Spring...             06
# 15            4700 Austell Rd, Austell, GA 30106, USA             22
# 16                810 Hurt Rd, Austell, GA 30106, USA             07
# 17  2049 Powder Springs Rd SW, Marietta, GA 30008,...             10
# 18   1500 Powers Ferry Rd SE, Marietta, GA 30067, USA             19
# 19          2380 Cobb Pkwy N, Kennesaw, GA 30152, USA             08
# 20     4336 Paces Ferry Rd SE, Atlanta, GA 30339, USA             05
# 21         315 Hillcrest Dr, Montezuma, GA 31063, USA             09
# 22             111 Ridgeway Rd, Milner, GA 30257, USA             17
# 23     4640 Dallas Hwy, Powder Springs, GA 30127, USA             13
# 24           3862 Cherokee St, Acworth, GA 30101, USA             26
# 25  3470 New MacLand Rd, Powder Springs, GA 30127,...             23
# 26  477 Veterans Memorial Hwy SW, Mableton, GA 301...             27
# 27         931 Windy Hill Rd, Marietta, GA 30008, USA             30
# 28         3858 Kemp Ridge Rd, Acworth, GA 30101, USA             28

# %%
gmaps = googlemaps.Client(key='AIzaSyBToPoTEF82tkEm9otXFQ2VHgl3bAumGjE')

# %%
origins = fire_facilities["FORMATTED_ADDRESS"].tolist()
print origins
# Out:
# [u'4550 Cowan Rd, Acworth, GA 30101, USA', u'1660 Mars Hill Rd, Acworth, GA 30101, USA', u'3540 Paul Samuel Rd NW, Kennesaw, GA 30152, USA', u'3800 Bells Ferry Rd, Kennesaw, GA 30144, USA', u'810 Brackett Rd, Marietta, GA 30066, USA', u'4431 Trickum Rd, Marietta, GA 30066, USA', u'Library Ln, Marietta, GA 30062, USA', u'3892 Oak Ln, Marietta, GA 30062, USA', u'1298 Hilton Dr, Marietta, GA 30062, USA', u'4400 Lower Roswell Rd, Marietta, GA 30068, USA', u'580 Terrell Mill Road SE, Marietta, GA 30067, USA', u'208 Barber Rd, Marietta, GA 30060, USA', u'1901 Cumberland Pkwy SE, Atlanta, GA 30339, USA', u'5656 Mableton Pkwy SW, Mableton, GA 30126, USA', u'5075 Hiram Lithia Springs Rd SW, Powder Springs, GA 30127, USA', u'4700 Austell Rd, Austell, GA 30106, USA', u'810 Hurt Rd, Austell, GA 30106, USA', u'2049 Powder Springs Rd SW, Marietta, GA 30008, USA', u'1500 Powers Ferry Rd SE, Marietta, GA 30067, USA', u'2380 Cobb Pkwy N, Kennesaw, GA 30152, USA', u'4336 Paces Ferry Rd SE, Atlanta, GA 30339, USA', u'315 Hillcrest Dr, Montezuma, GA 31063, USA', u'111 Ridgeway Rd, Milner, GA 30257, USA', u'4640 Dallas Hwy, Powder Springs, GA 30127, USA', u'3862 Cherokee St, Acworth, GA 30101, USA', u'3470 New MacLand Rd, Powder Springs, GA 30127, USA', u'477 Veterans Memorial Hwy SW, Mableton, GA 30126, USA', u'931 Windy Hill Rd, Marietta, GA 30008, USA', u'3858 Kemp Ridge Rd, Acworth, GA 30101, USA']

# %%
incidents = pd.read_csv("mins.csv")

# %%
incidents.head(5)
# Out:
#       inci_no        date  time zone station  \
# 0  00-0046003  12/16/2011   169   2F      02
# 1  11-0000002  01/01/2011   489  20F      20
# 2  11-0000003  01/01/2011   216   9C      09
# 3  11-0000004  01/01/2011   376   8E      08
# 4  11-0000005  01/01/2011     2  22C      22
#
#                                           address
# 0             274 Dunn AVE SE, MARIETTA GA, 30060
# 1  2823 HITCHCOCK MILL RUN NE, MARIETTA GA, 30062
# 2           384 WESTWOOD PL SW, AUSTELL GA, 30168
# 3  1950 BARRETT LAKES BLVD NW, KENNESAW GA, 30144
# 4            2255 WARREN DR SW, AUSTELL GA, 30106

# %%
incidents.shape
# Out:
# (210382, 6)

# %%
incidents.isnull().sum()
# Out:
# inci_no    0
# date       0
# time       0
# zone       0
# station    0
# address    0
# dtype: int64

# %% [markdown]
# ### Demo for First 50 Incidents

# %%
incidents_sample = incidents[:50]

google_stations = []
google_time = []


destinations = incidents_sample["address"].tolist()
now = datetime.now()
for destination in destinations:
    print "Calculating for the incident address: %s" % destination
    directions_result = gmaps.distance_matrix(origins, [destination], mode="driving", 
                                              departure_time=now, traffic_model="best_guess")
    times = []
    for row in directions_result["rows"]:
        times.append(row["elements"][0]["duration"]["value"] )
    min_time =  min(times)
    google_time.append(min_time)
    for index, time in enumerate(times):
        if time == min_time:
            station_number = fire_facilities["STATION NUMBER"][index]
            google_stations.append(station_number)   
    print "The station %s can arrive at the scene with the shortest time %s seconds" % (station_number, min_time)
    print
# Out:
# Calculating for the incident address: 274 Dunn AVE SE, MARIETTA GA, 30060
# The station 02 can arrive at the scene with the shortest time 295 seconds
#
# Calculating for the incident address: 2823 HITCHCOCK MILL RUN NE, MARIETTA GA, 30062
# The station 20 can arrive at the scene with the shortest time 342 seconds
#
# Calculating for the incident address: 384 WESTWOOD PL SW, AUSTELL GA, 30168
# The station 01 can arrive at the scene with the shortest time 470 seconds
#
# Calculating for the incident address: 1950 BARRETT LAKES BLVD NW, KENNESAW GA, 30144
# The station 08 can arrive at the scene with the shortest time 598 seconds
#
# Calculating for the incident address: 2255 WARREN DR SW, AUSTELL GA, 30106
# The station 22 can arrive at the scene with the shortest time 150 seconds
#
# Calculating for the incident address: 1337 OLD ALABAMA RD SW, MABLETON GA, 30126
# The station 01 can arrive at the scene with the shortest time 199 seconds
#
# Calculating for the incident address: 1370 COOKS FARM CT NW, KENNESAW GA, 30152
# The station 24 can arrive at the scene with the shortest time 224 seconds
#
# Calculating for the incident address: 5110 MEADOWS LAKE DR SW, POWDER SPRINGS GA, 30127
# The station 06 can arrive at the scene with the shortest time 112 seconds
#
# Calculating for the incident address: 2609 JESTERS CT NE, MARIETTA GA, 30068
# The station 03 can arrive at the scene with the shortest time 322 seconds
#
# Calculating for the incident address: 2964 FOREST CHASE TER NE, MARIETTA GA, 30066
# The station 25 can arrive at the scene with the shortest time 268 seconds
#
# Calculating for the incident address: 4180 LUTHER WARD RD SW, POWDER SPRINGS GA, 30127
# The station 13 can arrive at the scene with the shortest time 341 seconds
#
# Calculating for the incident address: 5225 SILHOUETTE LN SW, MABLETON GA, 30126
# The station 27 can arrive at the scene with the shortest time 213 seconds
#
# Calculating for the incident address: 5035 COWAN RD NW, ACWORTH GA, 30101
# The station 11 can arrive at the scene with the shortest time 113 seconds
#
# Calculating for the incident address: 3011 PACES MILL RD SE, ATLANTA GA, 30339
# The station 05 can arrive at the scene with the shortest time 28 seconds
#
# Calculating for the incident address: 2650 BENTLEY RD SE, MARIETTA GA, 30067
# The station 19 can arrive at the scene with the shortest time 310 seconds
#
# Calculating for the incident address: 3381 KENLAND RD SE, SMYRNA GA, 30082
# The station 07 can arrive at the scene with the shortest time 387 seconds
#
# Calculating for the incident address: 7251 CRESTSIDE DR SW, AUSTELL GA, 30168
# The station 01 can arrive at the scene with the shortest time 384 seconds
#
# Calculating for the incident address: 5274 CEDAR MILL DR SW, POWDER SPRINGS GA, 30127
# The station 13 can arrive at the scene with the shortest time 359 seconds
#
# Calculating for the incident address: 3655 CHEROKEE ST NW, KENNESAW GA, 30144
# The station 08 can arrive at the scene with the shortest time 454 seconds
#
# Calculating for the incident address: 5187 WHITE BLVD SW, MABLETON GA, 30126
# The station 27 can arrive at the scene with the shortest time 228 seconds
#
# Calculating for the incident address: 2756 COBB PKWY SE, SMYRNA GA, 30080
# The station 19 can arrive at the scene with the shortest time 501 seconds
#
# Calculating for the incident address: 3181 PINTO DR SW, POWDER SPRINGS GA, 30127
# The station 23 can arrive at the scene with the shortest time 232 seconds
#
# Calculating for the incident address: 2356 FOX DR NE, MARIETTA GA, 30066
# The station 12 can arrive at the scene with the shortest time 271 seconds
#
# Calculating for the incident address: 1605 VINEBROOK TER NW, KENNESAW GA, 30152
# The station 08 can arrive at the scene with the shortest time 330 seconds
#
# Calculating for the incident address: 1531 CORBIN PL SW, MARIETTA GA, 30008
# The station 07 can arrive at the scene with the shortest time 350 seconds
#
# Calculating for the incident address: 1886 STALLION PKWY SW, AUSTELL GA, 30106
# The station 22 can arrive at the scene with the shortest time 73 seconds
#
# Calculating for the incident address: 2844 COBB PKWY SE, ATLANTA GA, 30339
# The station 05 can arrive at the scene with the shortest time 469 seconds
#
# Calculating for the incident address: 2401 CHAUNCEY LN SW, MARIETTA GA, 30064
# The station 10 can arrive at the scene with the shortest time 114 seconds
#
# Calculating for the incident address: 2348 BENSON POOLE RD SE, SMYRNA GA, 30082
# The station 02 can arrive at the scene with the shortest time 201 seconds
#
# Calculating for the incident address: 3359 TIA TRCE NW, KENNESAW GA, 30152
# The station 08 can arrive at the scene with the shortest time 571 seconds
#
# Calculating for the incident address: 25 CECIL DR NE, MARIETTA GA, 30068
# The station 03 can arrive at the scene with the shortest time 287 seconds
#
# Calculating for the incident address: 4105 GEORGE BUSBEE PKWY NW, KENNESAW GA, 30144
# The station 16 can arrive at the scene with the shortest time 428 seconds
#
# Calculating for the incident address: 1472 TRIPLE CREEK CT NW, KENNESAW GA, 30144
# The station 08 can arrive at the scene with the shortest time 396 seconds
#
# Calculating for the incident address: 6155 FERNSTONE CT NW, ACWORTH GA, 30101
# The station 18 can arrive at the scene with the shortest time 234 seconds
#
# Calculating for the incident address: 2075 POWERS FERRY RD SE, MARIETTA GA, 30067
# The station 19 can arrive at the scene with the shortest time 210 seconds
#
# Calculating for the incident address: 3855 MEDICAL PARK DR SW, AUSTELL GA, 30106
# The station 22 can arrive at the scene with the shortest time 312 seconds
#
# Calculating for the incident address: 4400 AUSTELL POWDER SPRINGS RD SW, POWDER SPRINGS GA, 30127
# The station 23 can arrive at the scene with the shortest time 253 seconds
#
# Calculating for the incident address: 861 FRANKLIN RD SE, MARIETTA GA, 30067
# The station 02 can arrive at the scene with the shortest time 574 seconds
#
# Calculating for the incident address: 3600 FOWLER RD NW, ACWORTH GA, 30101
# The station 26 can arrive at the scene with the shortest time 269 seconds
#
# Calculating for the incident address: 6861 LANDMARK WAY SW, AUSTELL GA, 30168
# The station 01 can arrive at the scene with the shortest time 303 seconds
#
# Calculating for the incident address: 4037 DEVONSHIRE DR NE, MARIETTA GA, 30066
# The station 12 can arrive at the scene with the shortest time 259 seconds
#
# Calculating for the incident address: 2860 HAROLD DEAN DR NE, MARIETTA GA, 30066
# The station 12 can arrive at the scene with the shortest time 287 seconds
#
# Calculating for the incident address: 4371 EWING RD SW, AUSTELL GA, 30106
# The station 22 can arrive at the scene with the shortest time 275 seconds
#
# Calculating for the incident address: 4880 LOWER ROSWELL RD SE, MARIETTA GA, 30067
# The station 21 can arrive at the scene with the shortest time 209 seconds
#
# Calculating for the incident address: 2356 FOX DR NE, MARIETTA GA, 30066
# The station 12 can arrive at the scene with the shortest time 271 seconds
#
# Calculating for the incident address: 5008 HENSON DR SW, MABLETON GA, 30126
# The station 22 can arrive at the scene with the shortest time 209 seconds
#
# Calculating for the incident address: 2650 BENTLEY RD SE, MARIETTA GA, 30067
# The station 19 can arrive at the scene with the shortest time 310 seconds
#
# Calculating for the incident address: 1712 WINDY RIDGE LN SE, MARIETTA GA, 30067
# The station 19 can arrive at the scene with the shortest time 251 seconds
#
# Calculating for the incident address: 1920 CLAY RD SW, AUSTELL GA, 30106
# The station 22 can arrive at the scene with the shortest time 110 seconds
#
# Calculating for the incident address: 1608 HURT RD SW, MARIETTA GA, 30007
# The station 07 can arrive at the scene with the shortest time 245 seconds

# %%
import warnings
warnings.filterwarnings('ignore')

incidents_sample["google_station"] = google_stations
incidents_sample["google_time"] = google_time

# %%
incidents_sample
# Out:
#        inci_no        date  time zone station  \
# 0   00-0046003  12/16/2011   169   2F      02
# 1   11-0000002  01/01/2011   489  20F      20
# 2   11-0000003  01/01/2011   216   9C      09
# 3   11-0000004  01/01/2011   376   8E      08
# 4   11-0000005  01/01/2011     2  22C      22
# 5   11-0000009  01/01/2011   326   1B      01
# 6   11-0000010  01/01/2011   235  24C      24
# 7   11-0000011  01/01/2011   153   6B      06
# 8   11-0000012  01/01/2011   326   3B      03
# 9   11-0000014  01/01/2011   439  25B      25
# 10  11-0000015  01/01/2011   274  13H      13
# 11  11-0000016  01/01/2011   413   1C      01
# 12  11-0000017  01/01/2011   214  11A      11
# 13  11-0000018  01/01/2011   108   5B      05
# 14  11-0000021  01/01/2011   198  19A      19
# 15  11-0000022  01/01/2011   477   7D      07
# 16  11-0000024  01/01/2011    99   9B      09
# 17  11-0000025  01/01/2011   324  13D      13
# 18  11-0000026  01/01/2011   112  26E      26
# 19  11-0000027  01/01/2011   152   1C      01
# 20  11-0000029  01/01/2011   554   5B      05
# 21  11-0000032  01/01/2011   446  23F      23
# 22  11-0000033  01/01/2011   317  12F      12
# 23  11-0000035  01/01/2011   260   8C      08
# 24  11-0000036  01/01/2011   348   7B      07
# 25  11-0000037  01/01/2011   142  22F      22
# 26  11-0000038  01/01/2011   258   5B      05
# 27  11-0000039  01/01/2011   173  10C      10
# 28  11-0000040  01/01/2011   967   2B      02
# 29  11-0000041  01/01/2011   658  24G      24
# 30  11-0000043  01/01/2011   314   3B      03
# 31  11-0000044  01/01/2011  1239  26C      26
# 32  11-0000045  01/01/2011   406  26E      26
# 33  11-0000046  01/01/2011   262  18E      18
# 34  11-0000047  01/01/2011   775  19C      19
# 35  11-0000048  01/01/2011   399  22D      22
# 36  11-0000049  01/01/2011   509  23G      23
# 37  11-0000051  01/01/2011   332  55D     MF5
# 38  11-0000053  01/01/2011   309  11H      11
# 39  11-0000054  01/01/2011   461   9C      09
# 40  11-0000055  01/01/2011   292  12B      12
# 41  11-0000056  01/01/2011   413  12E      12
# 42  11-0000057  01/01/2011   303  22A      22
# 43  11-0000058  01/01/2011     6   3E      21
# 44  11-0000060  01/01/2011   243  12F      12
# 45  11-0000061  01/01/2011    47   1C      01
# 46  11-0000064  01/01/2011  1008  19A      19
# 47  11-0000065  01/01/2011   517  19C      19
# 48  11-0000066  01/01/2011   188  22F      22
# 49  11-0000067  01/01/2011   228   7B      07
#
#                                               address google_station  \
# 0                 274 Dunn AVE SE, MARIETTA GA, 30060             02
# 1      2823 HITCHCOCK MILL RUN NE, MARIETTA GA, 30062             20
# 2               384 WESTWOOD PL SW, AUSTELL GA, 30168             01
# 3      1950 BARRETT LAKES BLVD NW, KENNESAW GA, 30144             08
# 4                2255 WARREN DR SW, AUSTELL GA, 30106             22
# 5          1337 OLD ALABAMA RD SW, MABLETON GA, 30126             01
# 6           1370 COOKS FARM CT NW, KENNESAW GA, 30152             24
# 7   5110 MEADOWS LAKE DR SW, POWDER SPRINGS GA, 30127             06
# 8              2609 JESTERS CT NE, MARIETTA GA, 30068             03
# 9        2964 FOREST CHASE TER NE, MARIETTA GA, 30066             25
# 10   4180 LUTHER WARD RD SW, POWDER SPRINGS GA, 30127             13
# 11          5225 SILHOUETTE LN SW, MABLETON GA, 30126             27
# 12                5035 COWAN RD NW, ACWORTH GA, 30101             11
# 13           3011 PACES MILL RD SE, ATLANTA GA, 30339             05
# 14             2650 BENTLEY RD SE, MARIETTA GA, 30067             19
# 15               3381 KENLAND RD SE, SMYRNA GA, 30082             07
# 16            7251 CRESTSIDE DR SW, AUSTELL GA, 30168             01
# 17    5274 CEDAR MILL DR SW, POWDER SPRINGS GA, 30127             13
# 18            3655 CHEROKEE ST NW, KENNESAW GA, 30144             08
# 19             5187 WHITE BLVD SW, MABLETON GA, 30126             27
# 20                2756 COBB PKWY SE, SMYRNA GA, 30080             19
# 21         3181 PINTO DR SW, POWDER SPRINGS GA, 30127             23
# 22                 2356 FOX DR NE, MARIETTA GA, 30066             12
# 23          1605 VINEBROOK TER NW, KENNESAW GA, 30152             08
# 24              1531 CORBIN PL SW, MARIETTA GA, 30008             07
# 25           1886 STALLION PKWY SW, AUSTELL GA, 30106             22
# 26               2844 COBB PKWY SE, ATLANTA GA, 30339             05
# 27            2401 CHAUNCEY LN SW, MARIETTA GA, 30064             10
# 28          2348 BENSON POOLE RD SE, SMYRNA GA, 30082             02
# 29               3359 TIA TRCE NW, KENNESAW GA, 30152             08
# 30                 25 CECIL DR NE, MARIETTA GA, 30068             03
# 31     4105 GEORGE BUSBEE PKWY NW, KENNESAW GA, 30144             16
# 32        1472 TRIPLE CREEK CT NW, KENNESAW GA, 30144             08
# 33            6155 FERNSTONE CT NW, ACWORTH GA, 30101             18
# 34        2075 POWERS FERRY RD SE, MARIETTA GA, 30067             19
# 35         3855 MEDICAL PARK DR SW, AUSTELL GA, 30106             22
# 36  4400 AUSTELL POWDER SPRINGS RD SW, POWDER SPRI...             23
# 37             861 FRANKLIN RD SE, MARIETTA GA, 30067             02
# 38               3600 FOWLER RD NW, ACWORTH GA, 30101             26
# 39            6861 LANDMARK WAY SW, AUSTELL GA, 30168             01
# 40          4037 DEVONSHIRE DR NE, MARIETTA GA, 30066             12
# 41         2860 HAROLD DEAN DR NE, MARIETTA GA, 30066             12
# 42                4371 EWING RD SW, AUSTELL GA, 30106             22
# 43       4880 LOWER ROSWELL RD SE, MARIETTA GA, 30067             21
# 44                 2356 FOX DR NE, MARIETTA GA, 30066             12
# 45              5008 HENSON DR SW, MABLETON GA, 30126             22
# 46             2650 BENTLEY RD SE, MARIETTA GA, 30067             19
# 47         1712 WINDY RIDGE LN SE, MARIETTA GA, 30067             19
# 48                 1920 CLAY RD SW, AUSTELL GA, 30106             22
# 49                1608 HURT RD SW, MARIETTA GA, 30007             07
#
#     google_time
# 0           295
# 1           342
# 2           470
# 3           598
# 4           150
# 5           199
# 6           224
# 7           112
# 8           322
# 9           268
# 10          341
# 11          213
# 12          113
# 13           28
# 14          310
# 15          387
# 16          384
# 17          359
# 18          454
# 19          228
# 20          501
# 21          232
# 22          271
# 23          330
# 24          350
# 25           73
# 26          469
# 27          114
# 28          201
# 29          571
# 30          287
# 31          428
# 32          396
# 33          234
# 34          210
# 35          312
# 36          253
# 37          574
# 38          269
# 39          303
# 40          259
# 41          287
# 42          275
# 43          209
# 44          271
# 45          209
# 46          310
# 47          251
# 48          110
# 49          245
